Energy_ipe=[-0.00246,-0.00219,-0.00195,-0.00172,-0.00151,-0.00131,-0.00113,-0.00096,-0.00081,-0.00067,-0.00055,-0.00044,-0.00034,-0.00026,-0.00019,-0.00013,-0.00008,-0.00004,-0.00002,-0.00000,0.00000,-0.00000,-0.00002,-0.00004,-0.00007,-0.00011,-0.00015,-0.00021,-0.00027,-0.00033,-0.00040,-0.00048,-0.00056,-0.00065,-0.00074,-0.00083,-0.00093,-0.00104,-0.00115,-0.00126,-0.00137]

RC_thf=[-1.12667,-1.07033,-1.01400,-0.95766,-0.90133,-0.84500,-0.78866,-0.73233,-0.67599,-0.61966,-0.56333,-0.50699,-0.45066,-0.39433,-0.33799,-0.28166,-0.22533,-0.16900,-0.11267,-0.05634,0.00000,0.05634,0.11267,0.16900,0.22533,0.28166,0.33799,0.39433,0.45066,0.50699,0.56333,0.61966,0.67599,0.73233,0.78866,0.84499,0.90133,0.95766,1.01400,1.07033,1.12666]
Energy_thf=[-0.00298,-0.00267,-0.00237,-0.00209,-0.00185,-0.00161,-0.00139,-0.00118,-0.00100,-0.00083,-0.00068,-0.00054,-0.00042,-0.00032,-0.00023,-0.00016,-0.00010,-0.00005,-0.00002,-0.00001,0.00000,-0.00001,-0.00002,-0.00005,-0.00009,-0.00013,-0.00019,-0.00025,-0.00032,-0.00040,-0.00048,-0.00057,-0.00067,-0.00077,-0.00087,-0.00098,-0.00110,-0.00121,-0.00133,-0.00145,-0.00158]
1.13869
-0.00194

def invers(lst):
    lst_inv=lst.copy()
    lst_inv.reverse()
    return lst_inv

def signchange(lst):
    lst_sign=[]
    for value in lst:
        lst_sign.append(-value)
    return lst_sign

RC_vacuum_inv=invers(signchange(RC_vacuum))
Energy_vacuum_inv=invers(Energy_vacuum)

RC_an_inv=invers(signchange(RC_an))
Energy_an_inv=invers(Energy_an)


RC_ba_inv=invers(signchange(RC_ba))
Energy_ba_inv=invers(Energy_ba)

RC_bn_inv=invers(signchange(RC_bn))
Energy_bn_inv=invers(Energy_bn)

RC_dms_inv=invers(signchange(RC_dms))
Energy_dms_inv=invers(Energy_dms)

RC_ipe_inv=invers(signchange(RC_ipe))
Energy_ipe_inv=invers(Energy_ipe)

RC_thf_inv=invers(signchange(RC_thf))
Energy_thf_inv=invers(Energy_thf)


fig, ax = plt.subplots(ncols=1, figsize=(9,5.5))
ax.plot(RC_vacuum_inv,Energy_vacuum_inv, color='red',label='IRC_vacuum')
ax.plot(RC_an_inv,Energy_an_inv, color='blue',label='IRC_an')
ax.plot(RC_ba_inv,Energy_ba_inv,color='green',label='IRC_ba')
ax.plot(RC_bn_inv,Energy_bn_inv, color='orange',label='IRC_bn')
ax.plot(RC_dms_inv,Energy_dms_inv, color='purple',label='IRC_dms')
ax.plot(RC_ipe_inv,Energy_ipe_inv, color='deepskyblue',label='IRC_ipe')
ax.plot(RC_thf_inv,Energy_thf_inv, color='black',label='IRC_thf')

ax.scatter(RC_vacuum_inv,Energy_vacuum_inv,color='red')

ax.set_xlabel('Intrinsic Reaction Coordinate [$0.01\cdot$ bohr]',fontsize=font_norm)
ax.set_ylabel(r'Energy [Hartree]',fontsize=font_norm)
ax.tick_params(axis='y', labelsize=15)
ax.tick_params(axis='x', labelsize=15)

plt.ylim(-0.003,0.0001)
plt.xlim(-2,2)
RC_thf=[-1.12667,-1.07033,-1.01400,-0.95766,-0.90133,-0.84500,-0.78866,-0.73233,-0.67599,-0.61966,-0.56333,-0.50699,-0.45066,-0.39433,-0.33799,-0.28166,-0.22533,-0.16900,-0.11267,-0.05634,0.00000,0.05634,0.11267,0.16900,0.22533,0.28166,0.33799,0.39433,0.45066,0.50699,0.56333,0.61966,0.67599,0.73233,0.78866,0.84499,0.90133,0.95766,1.01400,1.07033,1.12666]
Energy_thf=[-0.00298,-0.00267,-0.00237,-0.00209,-0.00185,-0.00161,-0.00139,-0.00118,-0.00100,-0.00083,-0.00068,-0.00054,-0.00042,-0.00032,-0.00023,-0.00016,-0.00010,-0.00005,-0.00002,-0.00001,0.00000,-0.00001,-0.00002,-0.00005,-0.00009,-0.00013,-0.00019,-0.00025,-0.00032,-0.00040,-0.00048,-0.00057,-0.00067,-0.00077,-0.00087,-0.00098,-0.00110,-0.00121,-0.00133,-0.00145,-0.00158]
1.13869
-0.00194

def invers(lst):
    lst_inv=lst.copy()
    lst_inv.reverse()
    return lst_inv

def signchange(lst):
    lst_sign=[]
    for value in lst:
        lst_sign.append(-value)
    return lst_sign

RC_vacuum_inv=invers(signchange(RC_vacuum))
Energy_vacuum_inv=invers(Energy_vacuum)

RC_an_inv=invers(signchange(RC_an))
Energy_an_inv=invers(Energy_an)


RC_ba_inv=invers(signchange(RC_ba))
Energy_ba_inv=invers(Energy_ba)

RC_bn_inv=invers(signchange(RC_bn))
Energy_bn_inv=invers(Energy_bn)

RC_dms_inv=invers(signchange(RC_dms))
Energy_dms_inv=invers(Energy_dms)

RC_ipe_inv=invers(signchange(RC_ipe))
Energy_ipe_inv=invers(Energy_ipe)

RC_thf_inv=invers(signchange(RC_thf))
Energy_thf_inv=invers(Energy_thf)


fig, ax = plt.subplots(ncols=1, figsize=(9,5.5))
ax.plot(RC_vacuum_inv,Energy_vacuum_inv, color='red',label='IRC_vacuum')
ax.plot(RC_an_inv,Energy_an_inv, color='blue',label='IRC_an')
ax.plot(RC_ba_inv,Energy_ba_inv,color='green',label='IRC_ba')
ax.plot(RC_bn_inv,Energy_bn_inv, color='orange',label='IRC_bn')
ax.plot(RC_dms_inv,Energy_dms_inv, color='purple',label='IRC_dms')
ax.plot(RC_ipe_inv,Energy_ipe_inv, color='deepskyblue',label='IRC_ipe')
ax.plot(RC_thf_inv,Energy_thf_inv, color='black',label='IRC_thf')

ax.scatter(RC_vacuum_inv,Energy_vacuum_inv,color='red')

ax.set_xlabel('Intrinsic Reaction Coordinate [$0.01\cdot$ bohr]',fontsize=font_norm)
ax.set_ylabel(r'Energy [Hartree]',fontsize=font_norm)
ax.tick_params(axis='y', labelsize=15)
ax.tick_params(axis='x', labelsize=15)

plt.ylim(-0.003,0.0001)
plt.xlim(-2,2)
lgd=ax.legend(loc='center',fontsize=font_legen,bbox_to_anchor=(0.5, -0.35),fancybox=True, shadow=True, ncol=5)
plt.tight_layout()
